# %% [markdown]
# # pandas functions:

# %%
# 1) series: 

import pandas as pd

# %%
ser= pd.Series([1,2,3,4,5])
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data=pd.read_csv(r'C:\Users\Kumari Sapna\Downloads\IMDB-Movie-Data.csv')

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.size
# Out:
# 12000

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
# observations : 
# 1) this table is all about the movies realeased during the year 2006-2016.
#2) the minimum rating given is 1.90 and the maximum rating is 9.00
#3) the movie which earned the maximum amount is 936.630 millions 
#4) the shortest movie time is 66 minutes and the longest movie is 191 minutes.

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# observation: there are two columns in which some values is 'zero' which is revenue(millions), and merascore.

# %%
genre=data[['Genre']]
genre
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
df=data[['Genre', 'Director', 'Rating']]
df
# Out:
#                         Genre              Director  Rating
# 0     Action,Adventure,Sci-Fi            James Gunn     8.1
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott     7.0
# 2             Horror,Thriller    M. Night Shyamalan     7.3
# 3     Animation,Comedy,Family  Christophe Lourdelet     7.2
# 4    Action,Adventure,Fantasy            David Ayer     6.2
# ..                        ...                   ...     ...
# 995       Crime,Drama,Mystery             Billy Ray     6.2
# 996                    Horror              Eli Roth     5.5
# 997       Drama,Music,Romance            Jon M. Chu     6.2
# 998          Adventure,Comedy        Scot Armstrong     5.6
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld     5.3
#
# [1000 rows x 3 columns]

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data_indexing=pd.read_csv(r'C:\Users\Kumari Sapna\Downloads\IMDB-Movie-Data.csv' ,index_col='Title')
data_indexing
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
data_indexing.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
data_indexing.loc[['Suicide Squad']]
# Out:
#                Rank                     Genre  \
# Title
# Suicide Squad     5  Action,Adventure,Fantasy
#
#                                                      Description    Director  \
# Title
# Suicide Squad  A secret government agency recruits some of th...  David Ayer
#
#                                                           Actors  Year  \
# Title
# Suicide Squad  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
#
#                Runtime (Minutes)  Rating   Votes  Revenue (Millions)  \
# Title
# Suicide Squad                123     6.2  393727              325.02
#
#                Metascore
# Title
# Suicide Squad       40.0

# %%
df=data.loc[:,['Director']]
df
# Out:
#                  Director
# 0              James Gunn
# 1            Ridley Scott
# 2      M. Night Shyamalan
# 3    Christophe Lourdelet
# 4              David Ayer
# ..                    ...
# 995             Billy Ray
# 996              Eli Roth
# 997            Jon M. Chu
# 998        Scot Armstrong
# 999      Barry Sonnenfeld
#
# [1000 rows x 1 columns]

# %%
df=data.loc[:,['Genre','Actors']]
df
# Out:
#                         Genre  \
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
#                                                 Actors
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...
# ..                                                 ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996  Lauren German, Heather Matarazzo, Bijou Philli...
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# ...

# %%
df=data.iloc[:,2:4]
df
# Out:
#                         Genre  \
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
#                                            Description
# 0    A group of intergalactic criminals are forced ...
# 1    Following clues to the origin of mankind, a te...
# 2    Three girls are kidnapped by a man with a diag...
# 3    In a city of humanoid animals, a hustling thea...
# 4    A secret government agency recruits some of th...
# ..                                                 ...
# 995  A tight-knit team of rising investigators, alo...
# 996  Three American college students studying abroa...
# 997  Romantic sparks occur between two dance studen...
# ...

# %%
df=data.iloc[1:15,:]
df
# Out:
#     Rank                                    Title                       Genre  \
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# ...

# %%
df=data.iloc[4:5,:]
df
# Out:
#    Rank          Title                     Genre  \
# 4     5  Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description    Director  \
# 4  A secret government agency recruits some of th...  David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 4     6.2  393727              325.02       40.0

# %%
df=data.iloc[4:5,4:6]
df
# Out:
#      Director                                             Actors
# 4  David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...

# %%
df=data[((data['Rating']>=6) & (data['Rating']<=10))
       & ((data['Year']>=2007) & (data['Year']<=2015))
       & ((data['Revenue (Millions)']>=50) & (data['Revenue (Millions)']<=150) )]
df
# Out:
#      Rank                         Title                     Genre  \
# 1       2                    Prometheus  Adventure,Mystery,Sci-Fi
# 65     66  Kingsman: The Secret Service   Action,Adventure,Comedy
# 77     78          Inglourious Basterds       Adventure,Drama,War
# 82     83       The Wolf of Wall Street    Biography,Comedy,Crime
# 88     89             The Hateful Eight       Crime,Drama,Mystery
# ..    ...                           ...                       ...
# 971   972                     Disturbia    Drama,Mystery,Thriller
# 983   984                 Let's Be Cops                    Comedy
# 989   990                         Selma   Biography,Drama,History
# 994   995                     Project X                    Comedy
# 997   998        Step Up 2: The Streets       Drama,Music,Romance
#
#                                            Description           Director  \
# 1    Following clues to the origin of mankind, a te...       Ridley Scott
# ...

# %%
df=data.groupby('Actors')[['Rating']].mean().head(20)
df
# Out:
#                                                     Rating
# Actors
# Aamir Khan, Anushka Sharma, Sanjay Dutt,Boman I...     8.2
# Aamir Khan, Madhavan, Mona Singh, Sharman Joshi        8.4
# Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,S...     8.8
# Aaron Paul, Dominic Cooper, Imogen Poots, Scott...     6.5
# Aaron Poole, Kenneth Welsh,Daniel Fathers, Kath...     5.8
# Aaron Taylor-Johnson, Chloë Grace Moretz,Christ...     6.6
# Aaron Taylor-Johnson, Elizabeth Olsen, Bryan Cr...     6.4
# Aaron Taylor-Johnson, Nicolas Cage, Chloë Grace...     7.7
# Aaron Taylor-Johnson, Taylor Kitsch, Blake Live...     6.5
# Abbie Cornish, Dermot Mulroney, Justin Long,Die...     5.2
# Abigail Breslin, Wes Bentley, Logan Huffman,Ale...     4.7
# Adam Driver, Golshifteh Farahani, Nellie, Rizwa...     7.5
# Adam Pally, T.J. Miller, Thomas Middleditch,Sha...     5.6
# Adam Sandler, Andy Samberg, Selena Gomez, Kevin...     6.7
# Adam Sandler, David Spade, Paula Patton, Kathry...     5.7
# ...

# %%
data.groupby('Actors')[['Revenue (Millions)']].mean().sort_values(['Revenue (Millions)'], ascending=True).head(10)
# Out:
#                                                     Revenue (Millions)
# Actors
# Patrick Wilson, Jessica Biel, Haley Bennett, Vi...                0.00
# Jocelin Donahue, Jesse Bradford, Jesse Borrego,...                0.01
# Ellen Page, Evan Rachel Wood, Max Minghella,Cal...                0.01
# Lily Collins, Sam Claflin, Christian Cooke, Jai...                0.01
# Riley Keough, Jena Malone, Jessie Ok Gray, Cary...                0.01
# Bryan Cranston, Jennifer Garner, Beverly D'Ange...                0.01
# Connor Paolo, Nick Damici, Kelly McGillis, Greg...                0.02
# Dylan O'Brien, Britt Robertson, Victoria Justic...                0.02
# Emma Roberts, Kiernan Shipka, Lauren Holly, Luc...                0.02
# Matthew McConaughey, Naomi Watts, Ken Watanabe,...                0.02

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.drop('Metascore', axis=1).head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.dropna()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.dropna(axis=1)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df=data['Metascore'].fillna(10, inplace=True)
df

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore               0
# dtype: int64

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
revenue_mean=data['Rating'].mean()
revenue_mean
# Out:
# 6.723200000000003

# %%
def rating_group(rating):
    if rating>=8:
        return 'better'
    elif rating>=6:
        return 'good'
    else:
        return 'very good'

# %%
data['rating_category']=data['Rating'].apply(rating_group)

# %%
data[['Title','Director','Rating','rating_category']].head()
# Out:
#                      Title              Director  Rating rating_category
# 0  Guardians of the Galaxy            James Gunn     8.1          better
# 1               Prometheus          Ridley Scott     7.0            good
# 2                    Split    M. Night Shyamalan     7.3            good
# 3                     Sing  Christophe Lourdelet     7.2            good
# 4            Suicide Squad            David Ayer     6.2            good
